# %% [markdown]
# Import libtraries

# %%
import pandas as pd
from datetime import datetime, timedelta, date

# %% [markdown]
# Define constants

# %%
col_names = ['btrx_no', 'request_no', 'priority', 'priority_grp' 
    ,'name', 'project', 'initiator' 
    ,'supervisor', 'doer', 'step', 'status'
    ,'creation_dt', 'plan_dt'
    ,'completion_dt', 'analysis_plan_dt'
    ,'completion_status', 'preplanned_effort', 'planned_effort', 'fact_effort']

DAYS_2_COMPLETE = 20
default_completion_dt = datetime.now() + timedelta(days=DAYS_2_COMPLETE)
statuses_lst = ['Завершен нормально', 'ND']
projects_lst = [
 'Задачи на изменения'
,'B_Дополнительные сервисные услуги в договоре лизинга'
,'D_Сигналы геолокации (мониторинг маяков)'
#,'A_Система управления основными данными'
,'D_Оптимизация процесса ОБП'
,'B_Дополнительные сервисные  услуги в договоре лизинга'
,'А_Управление ликвидностью в режиме онлайн'
,'A_Оптимизация ОБП 2023 (Роботизация рутинных функций ОБП)'
#,'O_Audit'
,'B_Разработка Личных кабинетов клиента, агента'
,'D_"Экспресс 3.0"'
,'D_Формализация и автоматизация процесса привлечения финансирования'
,'C_Разработка и автоматизация процесса работы с тоталами/угонами'
,'A_Клиентское обслуживание через онлайн-канал'
#,'D_Рефакторинг кода и Оптимизация ландшафта КИС'
,'D_Актуализация PD-модели'
#,'C_Рефакторинг кода и Оптимизация ландшафта КИС'
,'A_Автоматизация досрочного погашения лизинговых платежей'
#,'ОИТ. Задачи ИТС360'
#,'A_Оптимизация работы с данными и их хранения'
,'D_Расширение филиальной сети _унификация организационной структуры КБ'
,'B_Система организации онлайн-продаж по дивизионам'
,'B_Непоставка'
,'D_Работа с агентами'
#,'A_ЭА'
,'D_Реализация активов'
,'D_Заключение и сопровождение сделок через ЭДО'
,'A_Заключение и сопровождение сделок через ЭДО'
,'B_Автоматизация процедур андеррайтинга'
,'D_Классификатор ПЛ 2021'
,'D_УСН'
#,'B_Развитие корпоративного портала'
,'B_Организация документооборота с внешними и внутренними контрагентами'
#,'C_BI'
,'D_Разработка и автоматизация рассылок по событиям'
,'B_Управление воронкой и регулярное администрирование продаж'
,'D_Разработка алгоритма расчета сальдо, включая процесс двухстороннего истребования'
,'D_Экспресс 3.0.'
,'D_Управление воронкой и регулярное администрирование продаж'
,'D_Система организации онлайн-продаж по дивизионам'
,'D_Автоматизация расчета премий'
#,'D_Создание организованной системы поддержки'
#,'A_Оптимизация пользовательского интерфейса'
,'D_Регламентация процесса передачи, учета и хранения ПТС/ПСМ и ключей'
,'D_ПДЗ 45+ Стратегия "Расторжение договора с изъятием ПЛ"'
#,'B_Автоматизация бизнес-процесса соблюдения требований Правил внутреннего контроля'
,'B_Регламентация процесса передачи, учета и хранения ПТС/ПСМ и ключей'
,'D_Анкета'
,'D_Плановое и досрочное закрытие ДЛ'
,'D_Замена стороны. Переуступка. Реструктуризация.'
,'C_Автоматизация досрочного погашения лизинговых платежей'
,'B_Сопровождение ДЛ: ТЗ + Регламент'
,'A_Автоматизация расчета премий'
,'B_Формализация и автоматизация процесса привлечения финансирования'
,'C_Автоматизация оценки предметов лизинга'
,'C_Сопровождение ДЛ'
,'B_Разработка и автоматизация процесса работы с тоталами/угонами'
#,'A_Новая архитектура и инфраструктура для WEB-CRM'
,'А_Оптимизация работы с корректирующими условиями_'
,'D_Автоматизация бизнес-процесса соблюдения требований Правил внутреннего контроля'
,'C_Расширение функциональности ELT на котировки грузовых ТС и Спецтехник'
,'D_Резервы МСФО 9'
,'C_Создание направления "Страховой брокер"'
#,'B_Создание организованной системы поддержки'
,'A_Актуализация PD-модели'
,'Проектный комитет'
#,'C_Реализация мероприятий в рамках требований ИБ'
,'D_Заключение и  сопровождение сделок через ЭДО'
,'O_Риски: Андеррайтинг'
,'C_Частичный перевод кадровых сервисов в электронную форму'
,'B_Разработка Положения и процесса структурирования, рассмотрения и принятия решения по лизинговым сделкам с индивидуальным рассмотрением'
,'А_Классификатор ПЛ 2021'
,'A_Разделение/сегментация процедуры заключения сделки по видам ПЛ'
,' C_Коробочный продукт для партнера'
,'МСФО'
,'А_Капитализация премий МКБ'
,'A_Расширение функциональности ELT на котировки грузовых ТС и Спецтехник'
,'A_Организация документооборота с внешними и внутренними контрагентами'
#,'A_Резервный центр обработки данных'
,'A_Автоматизация оценки предметов лизинга'
,''
,'A_Оптимизация процессов ПДЗ 45+'
,'A_Оптимизация работы с корректирующими условиями'
,'A_Оптимизация процессов  ПДЗ 45+'
#,'ОИТ. Внутренние задачи'
#,'А_Система управления основными данными'
,'НБКИ (проект)'
,'D_Договорная работа'
,'A_Оптимизация процесса ОБП'
,'A_Организация процесса приема-передачи силами мидл-подразделений'
,'A_Единая система по работе с проектами и ЗНИ'
,'O_Кросс_продажи_УРС'
,'A_Интеграция обращений с Банком Уралсиб через Sugar-CRM'
,'A_PD модель 2023'
#,'A_Создание универсального API для работы с каналами продаж'
#,'Переход на версию 1С УХ 3.2'
 ]

# %% [markdown]
# Read excel

# %%
from holidays import BusCalendar
cal = BusCalendar()

def isColumn(colname):
    return not colname.startswith("Unnamed:")

with pd.ExcelFile("backlog.xlsx") as xls:
    df_read = pd.read_excel(xls, skiprows=6, skipfooter=1, usecols = isColumn)#, names = col_names, dtype={'creation_dt':'datetime64[ns]', 'completion_dt':'datetime64[ns]'}, date_format='%d.%m.%y')
df_read.columns = col_names

df = df_read.copy()
df[['creation_dt', 'completion_dt']] = df[['creation_dt', 'completion_dt']].apply(pd.to_datetime, format='%d.%m.%Y')
df['creation_dt'] = df['creation_dt'].fillna(datetime(2023, 1, 1))
df['completion_dt'] = df['completion_dt'].fillna(default_completion_dt)
df['project'] = df['project'].fillna("ND")
df['completion_status'] = df['completion_status'].fillna("ND")
df['min_effort'] = df[['preplanned_effort', 'planned_effort', 'fact_effort']].min(axis=1)
df['preplanned_effort'] = df['preplanned_effort'].fillna(1)
df['planned_effort'] = df['planned_effort'].fillna(1)
df['fact_effort'] = df['fact_effort'].fillna(1)
df['max_effort'] = df[['preplanned_effort', 'planned_effort', 'fact_effort']].max(axis=1)
df['duration'] = df.apply(lambda row: cal.date_diff(row['creation_dt'], row['completion_dt']), axis=1)

df_ini = df.copy()

# %% [markdown]
# Filter dataframe and print stats

# %%
def print_stats(name, df):
        print(f"{name}\n\tcount:\t{df.duration.count()}\n\tduration average:\t{round(df.duration.mean())}\n\tduration median: \t{round(df.duration.median())}\n\teffort average:\t\t{round(df.planned_effort.mean())}\n\teffort median: \t\t{round(df.planned_effort.median())}")
    

start_dt = datetime(2022, 1, 1)
finish_dt = datetime(2023, 12, 31)
EFFORT = 'max_effort'


print(f"Uncleaned:\n{df_ini[['duration', 'max_effort', 'min_effort']].describe()}")


print(f"\nStats for projects: {projects_lst}\n and statuses: {statuses_lst}\n\n")
df = df_ini[(df_ini['duration'] >= 5)
            & (df_ini[EFFORT] >= 8)
            & (df_ini['project'].isin(projects_lst))
            & (df_ini['completion_status'].isin(statuses_lst))
            & (df_ini['priority_grp'] == 1)
            ]

print(f"Unfiltered:\n{df[['duration', 'max_effort', 'min_effort']].describe()}")
#df = df[(df['duration'] >= 10) & (df['duration'] <= 200)]


df_filtered = df[(df['creation_dt'] >= start_dt) & 
        (df['completion_dt'] >= finish_dt)]

print(f"\nFilters applied: creation date>={start_dt}; completion date >={finish_dt}\n")

print(f"Full set:\n{df_filtered[['duration', 'max_effort', 'min_effort']].describe()}")

df_8_40 = df_filtered[(df_filtered[EFFORT] >= 0)
                      & (df_filtered[EFFORT] < 40)
                      #& (df_filtered['duration'] >= 21)
                      #& (df_filtered['duration'] <= 90)
                      ]

print(f"\n8-40:\n{df_8_40[['duration', 'max_effort', 'min_effort']].describe()}")
            
df_40_80 = df_filtered[(df_filtered[EFFORT] >= 40)
                       & (df_filtered[EFFORT] < 80)
                       #& (df_filtered['duration'] >= 50)
                       #& (df_filtered['duration'] <= 169)
                       ]
print(f"\n40-80:\n{df_40_80[['duration', 'max_effort', 'min_effort']].describe()}")

df_80_200 = df_filtered[(df_filtered[EFFORT] >= 80)
                        & (df_filtered[EFFORT] < 200)
                        #& (df_filtered['duration'] >= 76)
                        #& (df_filtered['duration'] <= 212)
                        ]
print(f"\n80-200:\n{df_80_200[['duration', 'max_effort', 'min_effort']].describe()}")

df_filtered.to_csv('backlog_filtered.csv')
# Out:
# Uncleaned:
#           duration   max_effort   min_effort
# count  1630.000000  1630.000000  1149.000000
# mean     94.004908    41.497301    39.457528
# std     118.183712   110.988475   105.456754
# min       0.000000     1.000000     0.100000
# 25%      11.000000     1.000000     6.000000
# 50%      45.000000    12.000000    16.000000
# 75%     131.000000    40.000000    37.500000
# max     552.000000  1781.100000  1723.400000
#
# ...

# %%
#print(df_8_40[df_8_40.duration >= 200].loc[1394])
#print(df_read.loc[1394])
